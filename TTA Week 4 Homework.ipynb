# %%
#TASK 1 - new numbers

name = input("What's your name: ")
num1 = input("Choose your number 1: ")
num2 = input("Choose your number 2: ")
num3 = input("Choose your number 3: ")

new_file = open("numbers_file.txt","w")

new_file.write("Name: ")
new_file.write(name)
new_file.write("\n")
new_file.write("Number choice 1: ")
new_file.write(num1)
new_file.write("\n")
new_file.write("Number choice 2: ")
new_file.write(num2)
new_file.write("\n")
new_file.write("Number choice 3: ")
new_file.write(num3)
new_file.write("\n")

new_file.close()

# %%
#TASK 1 - Continued new numbers

name = input("What's your name: ")
num1 = input("Choose your number 1: ")
num2 = input("Choose your number 2: ")
num3 = input("Choose your number 3: ")

my_file = open("numbers_file.txt","a")
my_file.write("\n")
my_file.write("\n")
my_file.write("Name: ")
my_file.write(name)
my_file.write("\n")
my_file.write("Number choice 1: ")
my_file.write(num1)
my_file.write("\n")
my_file.write("Number choice 2: ")
my_file.write(num2)
my_file.write("\n")
my_file.write("Number choice 3: ")
my_file.write(num3)
my_file.write("\n")

my_file.close()

# %%
#TASK 1 - Continued new numbers READ

my_file = open("numbers_file.txt","r")
answers = my_file.read()

my_file.close()

print(answers)

# %%
#TASK 2 

grade_p = int(input("What percentage did you get? "))

def function1():
    if grade_p <= 10:
        grade = "Grade U"
    elif grade_p > 10 and grade_p <= 20:
        grade = "Grade F"
    elif grade_p > 20 and grade_p <= 30:
        grade = "Grade E"
    elif grade_p > 30 and grade_p <= 40:
        grade = "Grade D"
    elif grade_p > 40 and grade_p <= 50:
        grade = "Grade C"
    elif grade_p > 50 and grade_p <= 60:
        grade = "Grade B"
    elif grade_p > 60 and grade_p <= 70:
        grade = "Grade A"
    elif grade_p > 70:
        grade = "Grade A*"
    output = grade
    return output

grade1 = function1()

print(grade1)

# %%
#TASK 2 Continued


grade_p = int(input("What percentage did you get? "))

def function1():
    if grade_p <= 10:
        grade = "Grade U"
    elif grade_p > 10 and grade_p <= 20:
        grade = "Grade F"
    elif grade_p > 20 and grade_p <= 30:
        grade = "Grade E"
    elif grade_p > 30 and grade_p <= 40:
        grade = "Grade D"
    elif grade_p > 40 and grade_p <= 50:
        grade = "Grade C"
    elif grade_p > 50 and grade_p <= 60:
        grade = "Grade B"
    elif grade_p > 60 and grade_p <= 70:
        grade = "Grade A"
    elif grade_p > 70:
        grade = "Grade A*"
    output = grade
    return output

grade1 = function1()

print("That's equivalent to: ", grade1)

intended_grade = input("What grade were you hoping for? ")

def function2():
    if intended_grade == "A*":
        grade_z = 75
    elif intended_grade == "A":
        grade_z = 65
    elif intended_grade == "B":
        grade_z = 55
    elif intended_grade == "C":
        grade_z = 45
    elif intended_grade == "D":
        grade_z = 35
    elif intended_grade == "E":
        grade_z = 25
    elif intended_grade == "F":
        grade_z = 15
    elif intended_grade == "U":
        grade_z = 5
    output = grade_z
    return output
    
grade2 = function2()

print("If you got wanted a", intended_grade,"that's roughly", grade2, "%")

if grade2 > grade_p:
    print("Well you beat you're target, well done!")
elif grade2 < grade_p:
    print("Sorry to hear you were hoping for more, you can always go through clearing!")
elif grade2 == grade_p:
    print("You hit your target, nice one!")

# %%
#HOME LEARNING TASK

#Section 1

import numpy as np

array = np.arange(0,10)

print(array)

# %%
#Section 2

import numpy as np

array2 = np.arange(10,19).reshape(3,3)
print(array2>=10)

# %%
#Section 3

import numpy as np

array3 = np.arange(1,11)

list_even = []
list_odd = []

for i in array3:
    if i%2 == 0:
        list_even.append(i)
    else:
        list_odd.append(i)

print(list_even)

# %%
#Section 4 - UNFINISHED

import numpy as np

array4 = np.arange(1,11)

list_even = []
list_odd = []

for i in array4:
    if i%2 == 0:
        list_even.append(i)
    else:
        list_odd.append(i)

#for values in array4:
 #   if values == list_odd:
  #      array4.append(list_odd)


#I cannot seem to work out how to append/replace values within an Array. The method i would use for a list doesn't seem to work here.

# %%
#Section 5

import numpy as np

array5 = np.arange(1,9)

array5 = array5.reshape(2,4)

print(array5)

# %%
#Section 6 - NOT FINISHED

import numpy as np

a = np.arange(1,5).reshape(4,1)
b = np.arange(5,9).reshape(4,1)
print(a)
print(b)

c = np.dot(a,b) #There is some error here and I have not had time to work out why
print(c)

sum = np.sum(c)
print(sum)
