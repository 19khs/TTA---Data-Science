# %%
#TASK 1 - Number greater than 10

user_int = input("Please give me a whole number between 1 - 100: ")

while user_int.isnumeric() == False:
    user_int = input("Please give me a whole number between 1 - 100: ")

else:
    user_int = int(user_int)
    if user_int > 10:
        print("Number is greater than 10")
    else:
        print("Numbrt is smaller than 10")

# %%
#TASK 2 - Number greater than 10

user_int = input("Please give me a whole number between 1 - 100: ")

while user_int.isnumeric() == False:
    user_int = input("Please give me a whole number between 1 - 100: ")

else:
    user_int = int(user_int)
    if user_int > 10:
        print("Number is greater than 10")
    else:
        while user_int < 10:
            user_int += 1
        else:
            print("Number is greater than 10")

# %%
#TASK 3 - Flow Chart Code Exercise
#See flow chart on github.com/ohk19 for a visualisation of the below code

import time
import sys

options = []
print("Audi Car Garage UK")

q1 = input("Would you like to buy an Audi Car? [y/n]: ")
if q1 == "y":
    options.append("Car")
if q1 == "n":
    print("Thanks for looking.")
    sys.exit()
q2 = input("Would you like to add alloy wheels? [y/n]: ")
if q2 == "y":
    options.append("Alloys")
q3 = input("Would you like to add window tints? [y/n]: ")
if q3 == "y":
    options.append("Tints")
q4 = input("Would you like to add big speakers? [y/n]: ")
if q4 == "y":
    options.append("Speakers")
q5 = input("Are you able to pay by card? [y/n]: ")
if q5 == "y":
    print("Great! You have just purchased: ", options)
    sys.exit()
q6 = input("We only accept card unfortuntely, can this be arranged? [y/n]: ")
if q6 == "y":
    print("Great! You have just purchased: ", options)
elif q6 == "n":
    print("Unfortunately we're unable to sell you this car at this time")
    sys.exit()

# %%
#TASK 4 - Bike Price v2

price = 2000
year = 0

def function_1():
    price = 2000
    year = 0
    while price >= 1000:
        year = year + 1
        price = price - (price * 0.1)
        print(f"Year {year} = £{price}")
  

function_1()

# %%
#TASK 5 - User Number Input


def function_1():
    number1 = float(input("Number input 1: "))
    output = number1

    return output

number1 = function_1()


def function_2():
    number2 = float(input("Number input 2: "))
    output = number2 

    return output

number2 = function_2()
    

def procedure_1():
    
    operator = input("Choose operator from *, -, / or +: ")
    if operator == "+":
        print(number1 + number2)
    elif operator == "-":
        print(number1 - number2)
    elif operator == "/":
        print(number1 / number2)
    elif operator == "*":
        print(number1 * number2)


procedure_1()
